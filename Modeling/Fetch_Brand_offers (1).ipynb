# %% [markdown]
# This notebook returns offers for brands that fetch has in its database
#
# Approach:
#
# - If a brand has associated offers in the final DataFrame created by merging brands_df, category_df, and retail_df, we return all non-NaN offers for that brand. But, in cases where a brand has only NaN offers, we follow a two-step process:
#
# - Create a dictionary where keys are brand names with non-NaN offers, and values are sets of products associated with those brands.
#
# - Calculate Jaccard similarity between the set of products for the brand with all NaN offers and the sets of products for brands with non-NaN offers. We then order these brands based on their similarity scores and return the top offers from the most similar brands.

# %%
#Import libraries
import numpy as np
import pandas as pd

# %%
# Import dataset
brands_df = pd.read_csv('/content/drive/MyDrive/fetch/brand_category.csv')
category_df = pd.read_csv('/content/drive/MyDrive/fetch/categories.csv')
retail_df = pd.read_csv('/content/drive/MyDrive/fetch/offer_retailer.csv')

# %%
#brands_df
brands_df['BRAND'] = brands_df['BRAND'].str.lower()
brands_df['BRAND_BELONGS_TO_CATEGORY'] = brands_df['BRAND_BELONGS_TO_CATEGORY'].str.lower()

# %%
#categories_df
category_df['PRODUCT_CATEGORY'] = category_df['PRODUCT_CATEGORY'].str.lower()
category_df['IS_CHILD_CATEGORY_TO'] = category_df['IS_CHILD_CATEGORY_TO'].str.lower()

# %%
#retail_df
retail_df['RETAILER'] = retail_df['RETAILER'].str.lower()
retail_df['BRAND'] = retail_df['BRAND'].str.lower()

# %%
# Merge the dataframes based on the common column and keep only the required column
merged_df = brands_df.merge(category_df[['PRODUCT_CATEGORY', 'IS_CHILD_CATEGORY_TO']],
                            left_on='BRAND_BELONGS_TO_CATEGORY',
                            right_on='PRODUCT_CATEGORY',
                            how='left')

# Drop the columns that are not needed
merged_df.drop(columns=['PRODUCT_CATEGORY', 'RECEIPTS'], inplace=True)

# Rename the new column if needed
merged_df.rename(columns={'IS_CHILD_CATEGORY_TO': 'Product_category'}, inplace=True)
merged_df.rename(columns={'BRAND_BELONGS_TO_CATEGORY': 'Product'}, inplace=True)


# Save the merged dataframe to a new CSV file if needed
merged_df.to_csv('merged_brands.csv', index=False)

# %%
# Rename caseys gen store to caseys general store
merged_df['BRAND'] = merged_df['BRAND'].replace({'caseys gen store': 'caseys general store'})

# %%
# Merge the dataframes based on the common 'BRAND' column using a left join
merged_with_offers_df = merged_df.merge(retail_df, on='BRAND', how='left')

# Save the merged dataframe with offers to a new CSV file if needed
merged_with_offers_df.to_csv('merged_with_offers.csv', index=False)

# %%
# Reorder columns of merged_with_offers_df
ordered_df = merged_with_offers_df[['RETAILER', 'BRAND', 'Product', 'Product_category', 'OFFER']]

# %%
# Create an empty dictionary to store brands and their associated sets of unique products
brand_product_dict = {}

# Create a dictionary to keep track of offers for each brand
brand_offers = {}

# Iterate through the rows in the dataframe
for _, row in ordered_df.iterrows():
    brand = row['BRAND']
    product = row['Product']
    offer = row['OFFER']

    # Check if an offer exists for the brand (ignore rows where offer is NaN)
    if not pd.isna(offer):
        # Check if the brand has an entry in the dictionary
        if brand not in brand_product_dict:
            brand_product_dict[brand] = set()  # Use a set to store unique products

        # Add the product to the brand's set of unique products
        brand_product_dict[brand].add(product)

    # Keep track of offers for each brand
    if brand not in brand_offers:
        brand_offers[brand] = []

    # Add the offer to the brand's list of offers
    brand_offers[brand].append(offer)

# Filter brands where all offers are NaN
brands_with_nan_offers = [brand for brand, offers in brand_offers.items() if all(pd.isna(offer) for offer in offers)]

# Now, brand_product_dict contains brands as keys and sets of unique products as values
# And brands_with_nan_offers contains brands with all NaN offers
print("Brand Product Dictionary:")
print(brand_product_dict)

print("\nBrands with All NaN Offers:")
print(brands_with_nan_offers)
# Out:
# Brand Product Dictionary:
# {'caseys general store': {'jerky & dried meat', 'cookies', 'tea', 'tobacco products', 'chips', 'carbonated soft drinks', 'frozen pizza & pizza snacks', 'bakery', 'puffed snacks', 'beer', 'fruit juices', 'packaged vegetables', 'candy', 'cooking & baking', 'mature', 'household supplies', 'nuts & seeds', 'frozen desserts', 'energy drinks', 'water'}, 'dr pepper': {'carbonated soft drinks', 'cooking & baking'}, 'mountain dew': {'carbonated soft drinks'}, 'pepsi': {'carbonated soft drinks'}, 'cvs': {'skin care', 'cooking & baking', 'medicines & treatments', 'fruit juices'}, 'm&ms': {'candy'}, 'mcalisters deli': {'coffee', 'cookies', 'tea', 'dressings', 'sauces & marinades', 'chips', 'packaged meals & sides', 'wine', 'carbonated soft drinks', 'cheese', 'milk', 'packaged fruit & applesauce', 'bread', 'dips & salsa', 'bakery', 'frozen turkey', 'fruit juices', 'candy', 'pasta & noodles', 'leafy salads', 'frozen chicken', 'prepared meals', 'pickled goods', 'cooking & baking', 'fruit & vegetable snacks', 'frozen meals', 'soup & broth', 'water'}, 'gatorade': {'sports drinks', 'meal replacement beverages', 'medicines & treatments'}, 'coors light': {'beer', 'makeup'}, 'goya': {'cookies', 'sauces & marinades', 'dry pasta', 'deli counter', 'carbonated soft drinks', 'milk', 'packaged seafood', 'bread', 'dips & salsa', 'malt beverages', 'packaged meat', 'fruit juices', 'frozen appetizers', 'crackers', 'packaged vegetables', 'frozen fruits', 'drink mixes', 'frozen vegetables', 'pasta & noodles', 'rice & grains', 'frozen seafood', 'frozen chicken', 'pudding & gelatin', 'pickled goods', 'frozen meals', 'cooking & baking', 'nut butters & jam', 'soup & broth', 'water'}, 'thomas': {'bakery', 'frozen breakfast', 'bread'}, 'barilla': {'dry pasta', 'red pasta sauce', 'pesto sauce', 'chips'}, 'snickers': {'candy'}, 'sargento': {'cheese'}, 'entenmanns': {'bakery', 'cookies', 'snack cakes', 'wine'}, 'tostitos': {'chips', 'sauces & marinades', 'dips & salsa'}, 'sara lee': {'cereal, granola, & toaster pastries', 'cheese', 'bread', 'frozen desserts', 'bakery'}, 'ben and jerrys': {'frozen desserts'}, 'breyers': {'frozen breads & doughs', 'frozen desserts'}, 'twix': {'candy', 'cookies'}, 'dove': {'deodorant & antiperspirant', 'hair care', 'makeup', 'bath & body'}, 'skittles': {'candy', 'fruit juices'}, 'lifesavers': {'candy'}, 'extra': {'gum'}, 'gillette venus': {'hair removal'}, 'starburst': {'fruit & vegetable snacks', 'gum', 'candy'}, 'cheerios': {'cereal, granola, & toaster pastries'}, 'hidden valley ranch': {'sauces & marinades', 'dips & salsa', 'cooking & baking'}, 'ball park pop ups': {'bakery', 'bread'}, 'arnold brownberry oroweat': {'bakery', 'prepared meals', 'bread'}, 'welchs fruit snacks': {'fruit & vegetable snacks'}, 'sara lee artesano': {'bakery', 'bread'}, 'hellmanns best foods': {'condiments', 'sauces & marinades', 'dressings'}, 'orbit': {'gum'}, 'glad': {'prepared meals', 'household supplies', 'food storage', 'crackers'}, 'dixon': {'cooking & baking', 'makeup'}, 'klondike': {'frozen meals', 'frozen desserts'}, 'talenti': {'frozen meals', 'frozen desserts'}, '5 gum': {'gum'}, 'bai': {'drink mixes', 'water', 'fruit juices', 'tea'}, 'degree': {'deodorant & antiperspirant'}, 'core hydration': {'water'}, 'nature valley': {'chips', 'cereal, granola, & toaster pastries', 'trail mix', 'fruit & vegetable snacks', 'nuts & seeds', 'crackers', 'nut butters & jam', 'cookies', 'dips & salsa', 'candy'}, 'topo chico hard seltzer': {'hard seltzers, sodas, waters, lemonades & teas'}, 'bimbo': {'bakery', 'cookies', 'bread', 'snack cakes'}, 'beechnut': {'fruit & vegetable snacks', 'cookies', 'nuts & seeds', 'crackers'}, 'dove chocolate': {'candy'}, 'bugles': {'chips'}, 'ball park frank': {'frozen beef', 'packaged meat'}, 'marinela': {'candy', 'cookies', 'snack cakes'}, 'starry': {'carbonated soft drinks'}, 'aleve': {'medicines & treatments'}, 'cesar': {'dog supplies', 'cooking & baking', 'sauces & marinades', 'frozen chicken'}, 'fresh step': {'cooking & baking', ' ...
#
# Brands with All NaN Offers:
# ['equate', 'palmolive', 'dawn', 'barbasol', 'kroger', 'skintimate', 'dawn platinum', 'kirkland signature', 'red bull', 'coca-cola', 'ajax', 'bodycology', 'kinders', 'body fantasies', 'monster', 'ucreate', 'starbucks', 'gain', 'kraft', 'little debbie', 'up and up', 'hersheys', 'staedtler', 'mightygood', 'dailys', 'publix malta', 'bic', 'true living', 'chi chis', 'xtra', 'marketside', 'lays', 'clorox', 'reeses', 'powerade', 'old el paso', 'cheetos', 'cra-z-art', 'star wars', 'betty crocker', 'eggo', 'fireball', 'natures own', 'pringles', 'trueliving', 'las totally awesome', 'jif', 'nestle drumstick', 'tropicana', 'ole smoky', "kellogg's", 'rexall', 'michelob ultra', 'baby soft', 'quaker', 'yoplait', 'ruffles', 'tyson', 'studio selection', 'dg home', 'corona', 'heb', 'coca-cola zero', 'shorts variety pack', 'canada dry', 'arizona', 'bud light', 'dg body', 'yuengling', 'instacart', 'great value', 'sparkling ice', 'planters', 'doritos', 'pepperidge farm', 'dole', 'perdue', 'joy', 'la vostra', 'smart care', 'bells', 'captain morgan', 'mission', 'write dudes', 'hostess', 'barcel takis', "lay's", 'gasolina', 'wet ones', 'best brands', 'rc', 'sun', 'pure silk', 'velveeta', 'dogfish head', 'sprite', 'pillsbury', 'kings hawaiian', 'ush blueberries', 'aquafina', 'innovations', 'tower vodka', 'margaritaville', 'bodyarmor', 'ocean spray', 'sprite zero', 'roni', 'haagen-dazs', 'colgate toothpaste', 'borrasca', 'malibu rtd', 'heinz', 'simply lemonade', 'dish works', 'dawn ez squeeze', 'minute maid', 'kelloggs', 'miller lite', 'good chemistry', 'stella rosa', 'capri sun', "hellmann's/best foods", 'neutrogena', 'snyders of hanover', 'dawn simply clean', 'wegmans', 'cheez it', 'chobani', 'glaceau', 'white claw hard seltzer', 'kit kat', 'arm & hammer', 'gamesa', 'oscar mayer', 'totinos', 'modelo', 'predo', 'smirnoff ice', 'smirnoff', 'heineken', 'knorr', 'gold peak', 'prego', 'crest', 'luxury edition', 'lance', 'hersheys whoppers', 'jimmy dean', 'ed', 'frito lay', 'clorox fraganzia', 'belvino', 'baileys', 'parents choice', 'pure leaf', 'new belgium primus mural variety pack', 'lipton bottled iced tea', 'papermate', "m&m's", 'slim jim', 'bounty', 'minute maid premium', 'cloud break', 'sierra', 'folgers', 'diet coke caffeine free', 'malta india', 'smuckers uncrustables', 'celsius', 'digiorno', 'ragu', 'evriholder', 'pace', 'chex mix', 'bacardi party drinks bacardi usa', 'jose cuervo', 'barefoot', 'four loko pregame', 'sweetwater', 'land o lakes', "barq's", 'jim beam', 'mug root beer', 'bacardi', 'live for tomorrow', 'nerds', 'banquet', 'tasty', 'kahlua', 'santitas', 'old spice', 'buttercream', 'low hanging fruit', 'lipton', 'palo viejo palo ready', 'dunkin', "nature's bakery", 'cinnamon toast crunch', 'swanson', 'canyon oaks', 'carson ridge', "smucker's uncrustables", 'imperial', 'southern tier brewing company', 'kroger home sense', 'spice world', 'snack pack', 'bimbo bread', 'simply orange', 'honey bunches of oats', 'tide', 'grove co', 'lunchables', 'blue buffalo', 'spalife', 'simple truth', 'gerber', 'scott', 'propel', 'field and farm', 'sunkist', 'frito-lay', 'lagunitas', 'twizzlers', 'bacardi party drinks', 'cool whip', 'progresso', 'kind', 'bertolli', 'fritos', 'tesoro della regina', 'atkins', 'charmin', 'dasani', 'titos', '3 musketeers', 'cocktail artist', 'cape cod', 'meijer', 'ore-ida', 'uno mas', 'veuve du vernay', '99', 'brisk', 'new amsterdam pink whitney', 'dermassage', 'fisher-price', 'daves killer bread', 'corn nuts', 'red stripe', 'fruity pebbles', 'giant', 'rascal & friends', 'birds eye', 'lifewtr', 'big sipper', 'founders', 'oui by yoplait', 'smartfood', 'sutter home', 'kingsford', 'castello del poggio', 'remaining brnd', 'greenies', 'kevita', 'homeline', 'vlasic', 'philadelphia', 'cafe bustelo', 'dial', 'froot loops', 'eccentric', 'pinalen', 'rancho la gloria', 'kool aid', 'wellsley farms', 'skinnypop', 'samuel robert winery', 'philadelphia cream cheese', 'great lakes', "mott's", 'krusteaz', 'sunchips', 'parrot bay', 'quaker life' ...

# %%
def get_offers_for_brand(brand_name):
    # Filter the dataframe for the specified brand
    filtered_df = ordered_df[ordered_df['BRAND'] == brand_name]

    if filtered_df['OFFER'].isna().all():
        # Extract the products associated with the brand without offers
        products_for_brand_without_offers = set(filtered_df['Product'].unique())

        offer_similarities = []

        for other_brand, other_products in brand_product_dict.items():
            intersection = len(products_for_brand_without_offers.intersection(other_products))
            union = len(products_for_brand_without_offers.union(other_products))
            similarity = intersection / union

            if similarity > 0:
                offer_similarities.append((other_brand, similarity))

        if not offer_similarities:
            return "No similar brands with offers found."

        sorted_similar_brands = sorted(offer_similarities, key=lambda x: x[1], reverse=True)

        similar_brand_info = []
        for similar_brand, similarity_score in sorted_similar_brands:
            similar_brand_offers = brand_product_dict.get(similar_brand, [])
            similar_brand_actual_offers = ordered_df[ordered_df['BRAND'] == similar_brand]['OFFER'].unique()
            similar_brand_info.append({
                "Similar Brand": similar_brand,
                "Similarity Score": similarity_score,
                "Offers": similar_brand_actual_offers.tolist() if similar_brand_actual_offers.size > 0 else ["No offers"]
            })

        return similar_brand_info
    else:
        offers_for_brand = filtered_df['OFFER'].unique()
        unique_offers = list(set(offers_for_brand))

        if unique_offers:
            return [offer_line for offer_line in unique_offers]
        else:
            return "No offers found for the brand."

# %%
# Example usage:
brand_name = 'lays'  # Replace with the desired brand name
result = get_offers_for_brand(brand_name)
print(result)
# Out:
# [{'Similar Brand': 'tostitos', 'Similarity Score': 0.4, 'Offers': ['Tostitos® Toppers™']}, {'Similar Brand': 'nature valley', 'Similarity Score': 0.2727272727272727, 'Offers': ['Nature Valley™ Protein Granola']}, {'Similar Brand': 'bugles', 'Similarity Score': 0.25, 'Offers': ['General Mills™ snacks, select brands, spend $10']}, {'Similar Brand': 'natuchips', 'Similarity Score': 0.25, 'Offers': ['NatuChips® Plantain Chips']}, {'Similar Brand': 'emmys pop up', 'Similarity Score': 0.25, 'Offers': ["Emmy's Organics® Cookies OR Brownie Snaps"]}, {'Similar Brand': 'twix', 'Similarity Score': 0.2, 'Offers': ['TWIX®, select sizes', 'TWIX®, select varieties']}, {'Similar Brand': 'good humor', 'Similarity Score': 0.2, 'Offers': ['Good Humor Viennetta Frozen Vanilla Cake', "Reese's Peanut Butter Bar, 6 count, at GIANT OR MARTIN’S"]}, {'Similar Brand': 'brownie brittle', 'Similarity Score': 0.2, 'Offers': ['Brownie Brittle® Snacks, select varieties, buy 2']}, {'Similar Brand': 'hidden valley ranch', 'Similarity Score': 0.16666666666666666, 'Offers': ['Hidden Valley® Ranch Salad Dressing OR Secret Sauce, select varieties', 'Hidden Valley® Ranch Seasoning Mix Packet, 1 count', 'Hidden Valley® Ranch Seasoning, select varieties', 'Hidden Valley® Ranch Seasoning Shaker', 'Hidden Valley® Ranch Night Seasoning Mix, 1 count']}, {'Similar Brand': 'marinela', 'Similarity Score': 0.16666666666666666, 'Offers': ['Marinela® sweet baked goods, buy 2']}, {'Similar Brand': 'ratio', 'Similarity Score': 0.16666666666666666, 'Offers': [':ratio™ KETO* Friendly Cereal OR Granola']}, {'Similar Brand': 'barilla', 'Similarity Score': 0.14285714285714285, 'Offers': ['Barilla® Pesto Sauce', 'Barilla® Pasta, select varieties, buy 2', 'Barilla® pasta, select varieties, buy 3', 'Barilla® pasta, select varieties, buy 4', 'Barilla® pasta, select varieties, buy 2']}, {'Similar Brand': 'entenmanns', 'Similarity Score': 0.14285714285714285, 'Offers': ['Little Bites® Spend $10 at Walmart®']}, {'Similar Brand': 'bimbo', 'Similarity Score': 0.14285714285714285, 'Offers': ['Bimbo® sweet baked goods, buy 2']}, {'Similar Brand': 'beechnut', 'Similarity Score': 0.14285714285714285, 'Offers': ['Beech-Nut snacks, select varieties', 'Beech-Nut pouches, buy 8']}, {'Similar Brand': 'chosen foods', 'Similarity Score': 0.14285714285714285, 'Offers': ['Chosen Foods® Mayo, select varieties', 'Chosen Foods® Dressings']}, {'Similar Brand': 'red gold', 'Similarity Score': 0.125, 'Offers': ['Red Gold Tomato Ketchup', 'Red Gold Tomato Juice']}, {'Similar Brand': 'annies homegrown grocery', 'Similarity Score': 0.11764705882352941, 'Offers': ['Any General Mills™ products, buy 2\nGood Rewards Members Only', 'General Mills™ products, select brands, spend $35', 'General Mills™ products, select brands, spend $7 at Convenience Stores', 'General Mills™ products, select varieties, spend $12']}, {'Similar Brand': 'mcalisters deli', 'Similarity Score': 0.10344827586206896, 'Offers': ["Sign up for McAlister's Deli Rewards, tap for details"]}, {'Similar Brand': 'caseys general store', 'Similarity Score': 0.09090909090909091, 'Offers': ["Order from Casey's app or Caseys.com", "Spend $25 at Casey's", "Spend $5 in-store at Casey's", "Select beverages AND prepared food items at Casey's", "Visit OR order online from Casey's 7 times", "Spend $5 on single-serve prepared food items at Casey's", "12 Pack OR 2 Liter AND Whole Pizza Pie at Casey's", "Whole Pizza at Casey's", "Wings OR Cheesy Breadsticks at Casey's", "Whole Pizza Pie at Casey's", "Frozen OR Fountain Drink at Casey's", "Spend $10 in-store at Casey's", "Fresh bakery item, select varieties, at Casey's", "Whole pizza at Casey's", "12 Pack OR 2 Liter AND Whole Pizza at Casey's", "Frozen OR Fountain Drink at Casey's ", "Visit OR order online from Casey's 3 times", "Visit OR order online from Casey's 5 times", "12 pack OR 2 liter AND Whole Pizza at Casey's", "Whole Pizza at Casey's ", "Fresh Bakery Products at Casey's, select varieties", "Spend $10 on Case ...
