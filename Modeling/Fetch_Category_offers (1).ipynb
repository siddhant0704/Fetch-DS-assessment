# %% [markdown]
# This notebook returns offers for categories that fetch has in its database
#
# Approach:
#
# If a product category has associated offers in the final DataFrame created by merging brands_df, category_df, and retail_df, we return all non-NaN offers for that product category. In cases where a product category has only NaN offers, we follow a two-step process:
#
# Create a dictionary where keys are product category names with non-NaN offers, and values are sets of products associated with those brands.
#
# Calculate Jaccard similarity between the set of products for the product category with all NaN offers and the sets of products for product category with non-NaN offers. We then order these product categories based on their similarity scores and return the top offers from the most similar product categories.
#
# In addition, we have addressed another scenario where if a user searches for a product category that is not present in the dataframe, we employ BERT embeddings to create a representation for this category. We then calculate the cosine similarity between this category and all the product categories in the dataframe that have associated offers. Subsequently, we provide a list of product categories and their respective offers, focusing on those categories that exhibit significant similarity with the user's input product category.

# %%
#Import library
import numpy as np
import pandas as pd

# %%
#Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Load dataset
brands_df = pd.read_csv('/content/drive/MyDrive/fetch/brand_category.csv')
category_df = pd.read_csv('/content/drive/MyDrive/fetch/categories.csv')
retail_df = pd.read_csv('/content/drive/MyDrive/fetch/offer_retailer.csv')

# %%
#brands_df
brands_df['BRAND'] = brands_df['BRAND'].str.lower()
brands_df['BRAND_BELONGS_TO_CATEGORY'] = brands_df['BRAND_BELONGS_TO_CATEGORY'].str.lower()

# %%
#categories_df
category_df['PRODUCT_CATEGORY'] = category_df['PRODUCT_CATEGORY'].str.lower()
category_df['IS_CHILD_CATEGORY_TO'] = category_df['IS_CHILD_CATEGORY_TO'].str.lower()

# %%
#retail_df
retail_df['RETAILER'] = retail_df['RETAILER'].str.lower()
retail_df['BRAND'] = retail_df['BRAND'].str.lower()

# %%
# Merge the dataframes based on the common column and keep only the required column
merged_df = brands_df.merge(category_df[['PRODUCT_CATEGORY', 'IS_CHILD_CATEGORY_TO']],
                            left_on='BRAND_BELONGS_TO_CATEGORY',
                            right_on='PRODUCT_CATEGORY',
                            how='left')

# Drop the columns that are not needed
merged_df.drop(columns=['PRODUCT_CATEGORY', 'RECEIPTS'], inplace=True)

# Rename the new column if needed
merged_df.rename(columns={'IS_CHILD_CATEGORY_TO': 'Product_category'}, inplace=True)
merged_df.rename(columns={'BRAND_BELONGS_TO_CATEGORY': 'Product'}, inplace=True)


# Save the merged dataframe to a new CSV file if needed
merged_df.to_csv('merged_brands.csv', index=False)

# %%
merged_df['BRAND'] = merged_df['BRAND'].replace({'caseys gen store': 'caseys general store'})

# %%
# Merge the dataframes based on the common 'BRAND' column using a left join
merged_with_offers_df = merged_df.merge(retail_df, on='BRAND', how='left')

# Save the merged dataframe with offers to a new CSV file if needed
merged_with_offers_df.to_csv('merged_with_offers.csv', index=False)

# %%
ordered_df = merged_with_offers_df[['RETAILER', 'BRAND', 'Product', 'Product_category', 'OFFER']]

# %%
import pandas as pd

# Create a list to store categories with all NaN offers
categories_with_all_nan_offers = []

# Create a list to store categories with at least one non-NaN offer
categories_with_non_nan_offers = []

# Iterate through the rows in the dataframe
for category in ordered_df['Product_category'].unique():
    category_offers = ordered_df[ordered_df['Product_category'] == category]['OFFER']

    if all(pd.isna(offer) for offer in category_offers):
        categories_with_all_nan_offers.append(category)
    else:
        categories_with_non_nan_offers.append(category)

# Now, categories_with_all_nan_offers contains categories with all NaN offers
# categories_with_non_nan_offers contains categories with at least one non-NaN offer

print("Categories with All NaN Offers:")
print(categories_with_all_nan_offers)

print("\nCategories with Non-NaN Offers:")
print(categories_with_non_nan_offers)
# Out:
# Categories with All NaN Offers:
# ['baby & toddler', 'puffed snacks', 'oral care', 'spirits', 'home & garden']
#
# Categories with Non-NaN Offers:
# ['mature', 'health & wellness', 'deli & bakery', 'beverages', 'beauty', 'snacks', 'household supplies', 'alcohol', 'dairy', 'sports drinks & enhanced waters', 'pantry', 'frozen', 'pasta & noodles', 'frozen meat', 'candy', 'pasta sauce', 'animals & pet supplies', 'meat & seafood']

# %%
# Create a dictionary to store categories with at least one non-NaN offer and their associated products
categories_with_non_nan_offers_dict = {}

# Iterate through the rows in the dataframe
for category in ordered_df['Product_category'].unique():
    category_offers = ordered_df[ordered_df['Product_category'] == category]['OFFER']

    # Check if the category has at least one non-NaN offer
    if not all(pd.isna(offer) for offer in category_offers):
        # Get the associated products for the category
        associated_products = ordered_df[ordered_df['Product_category'] == category]['Product'].unique()

        # Add the category and its associated products to the dictionary
        categories_with_non_nan_offers_dict[category] = associated_products

# Now, categories_with_non_nan_offers_dict contains categories with at least one non-NaN offer as keys
# and their associated products as values

print("Categories with Non-NaN Offers and Their Associated Products:")
print(categories_with_non_nan_offers_dict)
# Out:
# Categories with Non-NaN Offers and Their Associated Products:
# {'mature': array(['tobacco products', 'mature'], dtype=object), 'health & wellness': array(['hair removal', 'bath & body', 'medicines & treatments',
#        'oral care', 'deodorant & antiperspirant', 'hair care',
#        'feminine hygeine', 'skin care', 'adult incontinence', 'first aid',
#        'foot care', 'eye care', 'sexual health'], dtype=object), 'deli & bakery': array(['bakery', 'prepared meals', 'leafy salads', 'deli counter'],
#       dtype=object), 'beverages': array(['carbonated soft drinks', 'coffee', 'fruit juices', 'tea', 'water',
#        'energy drinks', 'drink mixes', 'meal replacement beverages',
#        'vegetable juices'], dtype=object), 'beauty': array(['body fragrances', 'makeup', 'nail care', 'cosmetic tools'],
#       dtype=object), 'snacks': array(['dips & salsa', 'snack cakes', 'candy', 'chips', 'puffed snacks',
#        'nuts & seeds', 'fruit & vegetable snacks', 'pretzels', 'crackers',
#        'cookies', 'jerky & dried meat', 'snack mixes',
#        'pudding & gelatin', 'trail mix', 'dessert toppings'], dtype=object), 'household supplies': array(['household supplies', 'laundry supplies',
#        'household cleaning supplies', 'food storage', 'pest control'],
#       dtype=object), 'alcohol': array(['wine', 'beer', 'spirits', 'malt beverages',
#        'hard seltzers, sodas, waters, lemonades & teas', 'hard ciders'],
#       dtype=object), 'dairy': array(['cheese', 'yogurt', 'refrigerated doughs', 'butter & margarine',
#        'milk', 'eggs', 'cream', 'dairy', 'dairy alternatives'],
#       dtype=object), 'sports drinks & enhanced waters': array(['sports drinks'], dtype=object), 'pantry': array(['cooking & baking', 'bread', 'nut butters & jam',
#        'cereal, granola, & toaster pastries', 'rice & grains',
#        'sauces & marinades', 'packaged vegetables', 'condiments',
#        'packaged meat', 'soup & broth', 'packaged fruit & applesauce',
#        'packaged meals & sides', 'pickled goods', 'dressings',
#        'pasta & noodles', 'packaged seafood'], dtype=object), 'frozen': array(['frozen breakfast', 'frozen desserts',
#        'frozen pizza & pizza snacks', 'frozen meals', 'frozen vegetables',
#        'frozen fruits', 'frozen breads & doughs', 'frozen sides', 'ice',
#        'frozen', 'frozen appetizers', 'frozen plant-based meat'],
#       dtype=object), 'pasta & noodles': array(['dry pasta', 'fresh pasta'], dtype=object), 'frozen meat': array(['frozen chicken', 'frozen turkey', 'frozen seafood', 'frozen beef'],
#       dtype=object), 'candy': array(['gum'], dtype=object), 'pasta sauce': array(['red pasta sauce', 'alfredo & white pasta sauce', 'pesto sauce'],
#       dtype=object), 'animals & pet supplies': array(['dog supplies'], dtype=object), 'meat & seafood': array(['plant-based meat'], dtype=object)}

# %%
# Create an empty dictionary to store product categories and their associated sets of unique products
category_product_dict = {}

# Create a dictionary to keep track of offers for each category
category_offers = {}

# Iterate through the rows in the dataframe
for _, row in ordered_df.iterrows():
    product_category = row['Product_category']
    product = row['Product']
    offer = row['OFFER']

    # Check if an offer exists for the product category (ignore rows where offer is NaN)
    if not pd.isna(offer):
        # Check if the product category has an entry in the dictionary
        if product_category not in category_product_dict:
            category_product_dict[product_category] = set()  # Use a set to store unique products

        # Add the product to the product category's set of unique products
        category_product_dict[product_category].add(product)

    # Keep track of offers for each category
    if product_category not in category_offers:
        category_offers[product_category] = []

    # Add the offer to the category's list of offers
    category_offers[product_category].append(offer)

# Filter categories where all offers are NaN
categories_with_nan_offers = [category for category, offers in category_offers.items() if all(pd.isna(offer) for offer in offers)]

print("Category Product Dictionary:")
print(category_product_dict)

print("\nCategories with All NaN Offers:")
print(categories_with_nan_offers)
# Out:
# Category Product Dictionary:
# {'mature': {'mature', 'tobacco products'}, 'beverages': {'drink mixes', 'coffee', 'water', 'carbonated soft drinks', 'fruit juices', 'tea', 'energy drinks', 'meal replacement beverages'}, 'health & wellness': {'sexual health', 'hair care', 'oral care', 'medicines & treatments', 'hair removal', 'deodorant & antiperspirant', 'skin care', 'bath & body'}, 'snacks': {'nuts & seeds', 'chips', 'dips & salsa', 'candy', 'crackers', 'pudding & gelatin', 'trail mix', 'snack cakes', 'cookies', 'puffed snacks', 'jerky & dried meat', 'fruit & vegetable snacks'}, 'deli & bakery': {'leafy salads', 'bakery', 'prepared meals', 'deli counter'}, 'sports drinks & enhanced waters': {'sports drinks'}, 'alcohol': {'malt beverages', 'wine', 'hard seltzers, sodas, waters, lemonades & teas', 'beer', 'spirits'}, 'pantry': {'cooking & baking', 'pasta & noodles', 'sauces & marinades', 'packaged meat', 'bread', 'cereal, granola, & toaster pastries', 'packaged vegetables', 'nut butters & jam', 'pickled goods', 'dressings', 'packaged fruit & applesauce', 'condiments', 'rice & grains', 'packaged seafood', 'packaged meals & sides', 'soup & broth'}, 'pasta & noodles': {'dry pasta'}, 'dairy': {'cheese', 'eggs', 'yogurt', 'milk', 'refrigerated doughs'}, 'frozen': {'frozen breads & doughs', 'frozen plant-based meat', 'frozen vegetables', 'frozen meals', 'frozen pizza & pizza snacks', 'frozen breakfast', 'frozen desserts', 'frozen appetizers', 'frozen fruits'}, 'candy': {'gum'}, 'household supplies': {'food storage', 'laundry supplies', 'household supplies'}, 'beauty': {'makeup'}, 'meat & seafood': {'plant-based meat'}, 'frozen meat': {'frozen beef', 'frozen chicken', 'frozen turkey', 'frozen seafood'}, 'pasta sauce': {'red pasta sauce', 'alfredo & white pasta sauce', 'pesto sauce'}, 'animals & pet supplies': {'dog supplies'}}
#
# Categories with All NaN Offers:
# ['baby & toddler', 'puffed snacks', 'oral care', 'spirits', 'home & garden']

# %%
def get_similar_categories_and_offers(category_name):
    # Check if the category is in category_product_dict
    if category_name in category_product_dict:
        # If the category has non-NaN offers, return them
        category_offers = ordered_df[(ordered_df['Product_category'] == category_name) & (~ordered_df['OFFER'].isna())]['OFFER'].unique()
        return [(category_name, category_offers)]  # Just return the actual offers

    # Category not found in category_product_dict, find similar categories
    similarity_scores = {}

    # Get the set of products associated with the category (excluding NaN offers)
    products_for_category = set(ordered_df[(ordered_df['Product_category'] == category_name) & (~ordered_df['OFFER'].isna())]['Product'].unique())

    for other_category, other_products in category_product_dict.items():
        # Skip the same category
        if other_category == category_name:
            continue

        # Calculate Jaccard similarity between the two categories
        intersection = len(products_for_category.intersection(other_products))
        union = len(products_for_category.union(other_products))

        # Handle cases where both categories have no associated products (all NaN offers)
        if union == 0:
            similarity = 0.0
        else:
            similarity = intersection / union

        similarity_scores[other_category] = similarity

    # Sort similar categories by similarity score in descending order
    sorted_similar_categories = sorted(similarity_scores.items(), key=lambda x: x[1], reverse=True)

    # Filter out categories with a similarity score of 0
    similar_category_offers = [(similar_category, ordered_df[(ordered_df['Product_category'] == similar_category) & (~ordered_df['OFFER'].isna())]['OFFER'].unique()) for similar_category, similarity_score in sorted_similar_categories if similarity_score != 0]

    # If there are similar category offers, return them
    if similar_category_offers:
        return similar_category_offers

    # If there are no similar category offers, return "No offers"
    return [(category_name, ["No offers"])]

# %%
# Example usage:
category_name = 'snacks'  # Replace with the desired category name
similar_offers = get_similar_categories_and_offers(category_name)
print("Similar Offers for Category:", category_name)
for similar_category, offers in similar_offers:
    print(similar_category, offers)
# Out:
# Similar Offers for Category: snacks
# snacks ["M&M'S®, select sizes, buy 1"
#  "M&M'S® chocolate candies, select varieties"
#  'SNICKERS®, select sizes, buy 1'
#  'SNICKERS® chocolate candy bar, select varieties'
#  'Little Bites® Spend $10 at Walmart®' 'Tostitos® Toppers™'
#  "Order from Casey's app or Caseys.com" "Spend $25 at Casey's"
#  "Spend $5 in-store at Casey's"
#  "Select beverages AND prepared food items at Casey's"
#  "Visit OR order online from Casey's 7 times"
#  "Spend $5 on single-serve prepared food items at Casey's"
#  "12 Pack OR 2 Liter AND Whole Pizza Pie at Casey's"
#  "Whole Pizza at Casey's" "Wings OR Cheesy Breadsticks at Casey's"
#  "Whole Pizza Pie at Casey's" "Frozen OR Fountain Drink at Casey's"
#  "Spend $10 in-store at Casey's"
#  "Fresh bakery item, select varieties, at Casey's"
#  "Whole pizza at Casey's" "12 Pack OR 2 Liter AND Whole Pizza at Casey's"
#  "Frozen OR Fountain Drink at Casey's "
#  "Visit OR order online from Casey's 3 times"
#  "Visit OR order online from Casey's 5 times"
#  "12 pack OR 2 liter AND Whole Pizza at Casey's" "Whole Pizza at Casey's "
#  "Fresh Bakery Products at Casey's, select varieties"
#  "Spend $10 on Casey's branded packaged products"
#  "2 Pack OR 2 Liter AND Whole Pizza at Casey's"
#  "Select Beverages AND Prepared Food Item at Casey's"
#  "Fresh Bakery items, select varieties, at Casey's"
#  'Spend $5 on brisket mac & cheese sandwich OR other single-serve prepared food item'
#  'TWIX®, select sizes' 'TWIX®, select varieties'
#  'SKITTLES®, select varieties' 'SKITTLES®, select sizes' 'LIFE SAVERS®'
#  'LIFESAVERS®, any size, buy 1' 'STARBURST®, select sizes, buy 1'
#  'STARBURST®, select varieties'
#  'Hidden Valley® Ranch Salad Dressing OR Secret Sauce, select varieties'
#  'Hidden Valley® Ranch Seasoning Mix Packet, 1 count'
#  'Hidden Valley® Ranch Seasoning, select varieties'
#  'Hidden Valley® Ranch Seasoning Shaker'
#  'Hidden Valley® Ranch Night Seasoning Mix, 1 count'
#  "Sign up for McAlister's Deli Rewards, tap for details"
#  "Welch's®Fruit Snacks, select varieties, buy 2"
#  "Welch's® Zero Sugar Fruity Bites, 6 pack+, online at Amazon"
#  "Welch's® Fruit Snacks, select varieties, 6 count+, buy 3"
#  "Welch's® Fruit Snacks, 250 count, online at Amazon"
#  "Welch's® Juicefuls® Juicy Fruit Snacks, 14 count, at Target"
#  "Welch's® Fruit Snacks, select varieties, 6 count+, buy 2"
#  "Welch's®Fruit Snacks, spend $8"
#  "Welch's® Fruit 'n Yogurt® Snacks, 18 count, at Walmart"
#  "Welch's® Fruit Snacks, select varieties, 6 count+"
#  "Welch's® Juicefuls® Juicy Fruit Snacks, buy 2" 'Barilla® Pesto Sauce'
#  'Barilla® Pasta, select varieties, buy 2'
#  'Barilla® pasta, select varieties, buy 3'
#  'Barilla® pasta, select varieties, buy 4'
#  'Barilla® pasta, select varieties, buy 2'
#  'Nature Valley™ Protein Granola' 'Bimbo® sweet baked goods, buy 2'
#  'Beech-Nut snacks, select varieties' 'Beech-Nut pouches, buy 8'
#  'DOVE® Chocolate, select sizes, buy 1'
#  'DOVE® chocolate, select varieties'
#  'General Mills™ snacks, select brands, spend $10'
#  'Marinela® sweet baked goods, buy 2' "Jack Link's®, select varieties"
#  'Any General Mills™ products, buy 2\nGood Rewards Members Only'
#  'General Mills™ products, select brands, spend $35'
#  'General Mills™ products, select brands, spend $7 at Convenience Stores'
#  'General Mills™ products, select varieties, spend $12'
#  'Glad® Trash Bags, 4 OR 8 Gallon'
#  'Glad® ForceFlex Max Strength Trash Bags'
#  'Good Humor Viennetta Frozen Vanilla Cake'
#  "Reese's Peanut Butter Bar, 6 count, at GIANT OR MARTIN’S"
#  'Shop 2 times at Safeway' 'Spend $210 at Safeway' 'Any Safeway receipt'
#  'Spend $115 at Safeway' 'Spend $90 at Safeway' 'GOYA® Coconut Water'
#  'GOYA® Adobo Seasoning, 8 ounce+' 'Crunchmaster® Crackers, spend $4'
#  'Brownie Brittle® Snacks, select varieties, buy 2'
#  'Chosen Foods® Mayo, select varieties' 'Chosen Foods® Dressings'
#  'Any Albertsons receipt' 'Shop 2 times at Albertsons'
#  'Spend $65 at Albertsons' 'Spend $110 at Albertsons'
#  'Spend $220 at Albertsons' 'NatuChips® Plantain Chips'
#  ':ratio™ KETO* Friendly Cereal OR Granola' 'Red Gold Tomato Ketchup'
#  'Red Gold Tomato Juice' "Emmy's Organics® Cookies OR Brownie Snaps"
#  'Perfect Keto Barista Blend Collagen & MCTs, online at Amazon'
#  'Perfect Keto Beauty + Sleep Collagen, online at Amazon'
#  'Perfect Keto Bars, online at Amazon'
#  'Perfect Keto Collagen Peptides, online at Amazon'
#  'Perfect Keto MCT Oil Powder, online at Amazon'
#  'Perfect Keto Super Reds, online at Amazon'
#  'Perfect Keto Exogenous Ketones Powder, online at Amazon'
#  'Envy Apples pre-packed bags' 'Envy Apples, pre-packed bags'
#  "Gorton's, at select retailers"
#  "Gorton's Air Fried Butterfly Shrimp, at Walmart"
#  "Gorton's at select retailers"]

# %%
import torch
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Define the BERT model and tokenizer
model_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 46.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 27.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 64.5 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 26.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.0

# %%
# Define the function to compute category similarity and get offers
def get_similar_categories_and_offers_with_similarity(input_category, top_n=5):
    # Tokenize and encode the input category
    input_tokens = tokenizer(input_category, return_tensors='pt', padding=True, truncation=True)

    # Get the BERT embeddings for the input category
    with torch.no_grad():
        input_category_embedding = model(**input_tokens).last_hidden_state.mean(dim=1)  # Mean pooling

    # Calculate cosine similarity with all categories that have offers
    category_similarities = {}
    for category in ordered_df[~ordered_df['OFFER'].isna()]['Product_category'].unique():
        category_tokens = tokenizer(category, return_tensors='pt', padding=True, truncation=True)
        category_embedding = model(**category_tokens).last_hidden_state.mean(dim=1)
        similarity = cosine_similarity(input_category_embedding.detach().numpy(), category_embedding.detach().numpy())
        category_similarities[category] = similarity[0][0]

    # Sort categories by similarity score in descending order
    sorted_similar_categories = sorted(category_similarities.items(), key=lambda x: x[1], reverse=True)

    # Select the top N similar categories
    top_similar_categories = sorted_similar_categories[:top_n]

    # Retrieve and return the offers and their associated similarity scores for the selected similar categories
    similar_category_offers = []
    for similar_category, similarity_score in top_similar_categories:
        offers = ordered_df[(ordered_df['Product_category'] == similar_category) & (~ordered_df['OFFER'].isna())]['OFFER'].unique()
        similar_category_offers.append((similar_category, offers.tolist(), similarity_score))

    if not similar_category_offers:
        return f"No similar categories found for {input_category}."
    return similar_category_offers

# %%
# Example usage:
input_category = 'chips'  # Replace with the desired input category
similar_offers = get_similar_categories_and_offers_with_similarity(input_category)
for similar_category, offers, similarity_score in similar_offers:
    print(f"Similar Category: {similar_category}")
    print(f"Similarity Score: {similarity_score}")
    print(f"Offers: {', '.join(offers)}\n")
# Out:
# Similar Category: snacks
# Similarity Score: 0.9346911311149597
# Offers: M&M'S®, select sizes, buy 1, M&M'S® chocolate candies, select varieties, SNICKERS®, select sizes, buy 1, SNICKERS® chocolate candy bar, select varieties, Little Bites® Spend $10 at Walmart®, Tostitos® Toppers™, Order from Casey's app or Caseys.com, Spend $25 at Casey's, Spend $5 in-store at Casey's, Select beverages AND prepared food items at Casey's, Visit OR order online from Casey's 7 times, Spend $5 on single-serve prepared food items at Casey's, 12 Pack OR 2 Liter AND Whole Pizza Pie at Casey's, Whole Pizza at Casey's, Wings OR Cheesy Breadsticks at Casey's, Whole Pizza Pie at Casey's, Frozen OR Fountain Drink at Casey's, Spend $10 in-store at Casey's, Fresh bakery item, select varieties, at Casey's, Whole pizza at Casey's, 12 Pack OR 2 Liter AND Whole Pizza at Casey's, Frozen OR Fountain Drink at Casey's , Visit OR order online from Casey's 3 times, Visit OR order online from Casey's 5 times, 12 pack OR 2 liter AND Whole Pizza at Casey's, Whole Pizza at Casey's , Fresh Bakery Products at Casey's, select varieties, Spend $10 on Casey's branded packaged products, 2 Pack OR 2 Liter AND Whole Pizza at Casey's, Select Beverages AND Prepared Food Item at Casey's, Fresh Bakery items, select varieties, at Casey's, Spend $5 on brisket mac & cheese sandwich OR other single-serve prepared food item, TWIX®, select sizes, TWIX®, select varieties, SKITTLES®, select varieties, SKITTLES®, select sizes, LIFE SAVERS®, LIFESAVERS®, any size, buy 1, STARBURST®, select sizes, buy 1, STARBURST®, select varieties, Hidden Valley® Ranch Salad Dressing OR Secret Sauce, select varieties, Hidden Valley® Ranch Seasoning Mix Packet, 1 count, Hidden Valley® Ranch Seasoning, select varieties, Hidden Valley® Ranch Seasoning Shaker, Hidden Valley® Ranch Night Seasoning Mix, 1 count, Sign up for McAlister's Deli Rewards, tap for details, Welch's®Fruit Snacks, select varieties, buy 2, Welch's® Zero Sugar Fruity Bites, 6 pack+, online at Amazon, Welch's® Fruit Snacks, select varieties, 6 count+, buy 3, Welch's® Fruit Snacks, 250 count, online at Amazon, Welch's® Juicefuls® Juicy Fruit Snacks, 14 count, at Target, Welch's® Fruit Snacks, select varieties, 6 count+, buy 2, Welch's®Fruit Snacks, spend $8, Welch's® Fruit 'n Yogurt® Snacks, 18 count, at Walmart, Welch's® Fruit Snacks, select varieties, 6 count+, Welch's® Juicefuls® Juicy Fruit Snacks, buy 2, Barilla® Pesto Sauce, Barilla® Pasta, select varieties, buy 2, Barilla® pasta, select varieties, buy 3, Barilla® pasta, select varieties, buy 4, Barilla® pasta, select varieties, buy 2, Nature Valley™ Protein Granola, Bimbo® sweet baked goods, buy 2, Beech-Nut snacks, select varieties, Beech-Nut pouches, buy 8, DOVE® Chocolate, select sizes, buy 1, DOVE® chocolate, select varieties, General Mills™ snacks, select brands, spend $10, Marinela® sweet baked goods, buy 2, Jack Link's®, select varieties, Any General Mills™ products, buy 2
# Good Rewards Members Only, General Mills™ products, select brands, spend $35, General Mills™ products, select brands, spend $7 at Convenience Stores, General Mills™ products, select varieties, spend $12, Glad® Trash Bags, 4 OR 8 Gallon, Glad® ForceFlex Max Strength Trash Bags, Good Humor Viennetta Frozen Vanilla Cake, Reese's Peanut Butter Bar, 6 count, at GIANT OR MARTIN’S, Shop 2 times at Safeway, Spend $210 at Safeway, Any Safeway receipt, Spend $115 at Safeway, Spend $90 at Safeway, GOYA® Coconut Water, GOYA® Adobo Seasoning, 8 ounce+, Crunchmaster® Crackers, spend $4, Brownie Brittle® Snacks, select varieties, buy 2, Chosen Foods® Mayo, select varieties, Chosen Foods® Dressings, Any Albertsons receipt, Shop 2 times at Albertsons, Spend $65 at Albertsons, Spend $110 at Albertsons, Spend $220 at Albertsons, NatuChips® Plantain Chips, :ratio™ KETO* Friendly Cereal OR Granola, Red Gold Tomato Ketchup, Red Gold Tomato Juice, Emmy's Organics® Cookies OR Brownie Snaps, Perfect Keto Barista Blend Collagen & MCTs, online at Amazon, Perfect Keto Beauty + Sleep Collagen, online at Amazon, Perfect Keto Bars, online at Amazon, Perfect Keto Collagen Peptides, online at Amazon, Perfect Keto MCT Oil Powder, online at Amazon, Perfect Keto Super Reds, online at Amazon, Perfect Keto Exogenous Ketones Powder, online at Amazon, Envy Apples pre-packed bags, Envy Apples, pre-packed bags, Gorton's, at select retailers, Gorton's Air Fried Butterfly Shrimp, at Walmart, Gorton's at select retailers
#
# Similar Category: candy
# Similarity Score: 0.9277099370956421
# Offers: EXTRA®, select varieties, EXTRA®, select sizes, ORBIT®, select sizes, buy 1, ORBIT®, select varieties, RESPAWN® by 5® GUM, at Walmart, STARBURST®, select sizes, buy 1, STARBURST®, select varieties
#
# Similar Category: pantry
# Similarity Score: 0.9064772129058838
# Offers: GOYA® Coconut Water, GOYA® Adobo Seasoning, 8 ounce+, Thomas'® Bagel Thins®, buy 2, Thomas'®, select varieties, spend $10, Thomas'® Bagel Thins, Sara Lee® bread, select varieties, buy 2 at Walmart®, Sara Lee® bread select varieties, buy 2, Sara Lee® Delightful bread, buy 2, Dr Pepper®, Regular OR Zero Sugar Strawberries and Cream 12 pack, at select retailers, Cheerios™ Oat Crunch Berry Cereal, BallPark® buns, buy 2, Arnold, Brownberry, Oroweat® Small Slice bread, at Walmart, Arnold, Brownberry, Oroweat® Keto bread, buy 2, Arnold® Grains Almighty, Hellmann's® OR Best Foods® Garlic Aioli OR Spicy Mayonnaise, Hellmann's® OR Best Foods® AND Sargento® Cheese Slices, Hellmann's | Best Foods Vegan Dressing or Spread, Dixon® Safety Carpenter Pencil, 10 count, at Lowe’s®, Order from Casey's app or Caseys.com, Spend $25 at Casey's, Spend $5 in-store at Casey's, Select beverages AND prepared food items at Casey's, Visit OR order online from Casey's 7 times, Spend $5 on single-serve prepared food items at Casey's, 12 Pack OR 2 Liter AND Whole Pizza Pie at Casey's, Whole Pizza at Casey's, Wings OR Cheesy Breadsticks at Casey's, Whole Pizza Pie at Casey's, Frozen OR Fountain Drink at Casey's, Spend $10 in-store at Casey's, Fresh bakery item, select varieties, at Casey's, Whole pizza at Casey's, 12 Pack OR 2 Liter AND Whole Pizza at Casey's, Frozen OR Fountain Drink at Casey's , Visit OR order online from Casey's 3 times, Visit OR order online from Casey's 5 times, 12 pack OR 2 liter AND Whole Pizza at Casey's, Whole Pizza at Casey's , Fresh Bakery Products at Casey's, select varieties, Spend $10 on Casey's branded packaged products, 2 Pack OR 2 Liter AND Whole Pizza at Casey's, Select Beverages AND Prepared Food Item at Casey's, Fresh Bakery items, select varieties, at Casey's, Spend $5 on brisket mac & cheese sandwich OR other single-serve prepared food item, Tyson Products, select varieties, spend $20 at Sam's Club, Nature Valley™ Protein Granola, CESAR® Wet Dog Food, spend $20, CESAR® Wet Dog Food Singles, Michael Angelo's® OR Rao's® Frozen Entrees, spend $10, Rao's® Frozen Pizza, Rao's®, Pasta OR Sauce, spend $10, Bimbo® sweet baked goods, buy 2, Sign up for McAlister's Deli Rewards, tap for details, Country Crock® Plant Based Butter at Walmart, Country Crock® Plant Based Cream at Walmart, Butterball, select varieties, spend $10 at Dillons Food Store, Butterball, select varieties, spend $10 at Ralphs, Butterball, select varieties, Spend $10 at Ruler Foods, Butterball, select varieties, spend $10 at King Soopers, Butterball, select varieties, spend $10 at Fred Meyer, Butterball, select varieties, spend $10 at Kroger, Butterball, select varieties, spend $10 at Smith's, Butterball, select varieties, spend $10 at Food 4 Less, Butterball, select varieties, spend $10 at Fry's Food Store, Butterball, select varieties, spend $10 at QFC, Butterball, select varieties, spend $10 at Mariano's, Butterball, select varieties, spend $10 at Pick 'n Save OR Metro Market, Artesano® buns, buy 2 at Walmart®, Hidden Valley® Ranch Salad Dressing OR Secret Sauce, select varieties, Hidden Valley® Ranch Seasoning Mix Packet, 1 count, Hidden Valley® Ranch Seasoning, select varieties, Hidden Valley® Ranch Seasoning Shaker, Hidden Valley® Ranch Night Seasoning Mix, 1 count, Simply Organic Seasoning Mixes OR Spices, Wesson® Oil Products, :ratio™ KETO* Friendly Cereal OR Granola, Bays® English Muffins, Sir Kensington's® Condiments, buy 2, Sir Kensington's® Condiments, Tyson Products, select varieties, spend $15 at Walmart, Spend $10 at Subway, Spend $25 at Subway, Spend $15 at Subway, Spend $35 at Subway, Sara Lee® or Alfaros® Artesano bread, buy 5, Sara Lee® or Alfaros® Artesano bread, spend $8, Sara Lee® or Alfaros® Artesano bread, buy 2, Sara Lee® or Alfaros® Artesano bread, spend $20, Red Gold Tomato Ketchup, Red Gold Tomato Juice, Chosen Foods® Mayo, select varieties, Chosen Foods® Dressings, Envy Apples pre-packed bags, Envy Apples, pre-packed bags, The ...
# Good Rewards Members Only, General Mills™ products, select brands, spend $35, General Mills™ products, select brands, spend $7 at Convenience Stores, General Mills™ products, select varieties, spend $12, Back to the Roots Grow Seed Starting Pots OR Germination Trays, at Walmart or Target, Back to the Roots Soils, select varieties and sizes, at Walmart, Back to the Roots Dry Plant Food, 5 pounds, at The Home Depot, Back to the Roots Garden Soil, 1 cubic foot, at Lowe's Home Improvement, Back to the Roots Raised Bed Gardening Kit with Soil, Seeds and Plant Food, at Target, Back to the Roots Microgreens Grow Kit OR Seed Refill at Walmart, Back to the Roots Soils, select varieties and sizes, at Lowes, Back to the Roots Soils, select varieties, at Walmart or Lowes, Back to the Roots Grow Kits at Walmart or The Home Depot, Back to the Roots Grow Hydroponic Grow Kit OR Refill Bundle at Walmart, Back to the Roots Seeds, at Walmart, Back to the Roots Organic Kits and Planters, at Target, Back to the Roots Potting Mix, 1 cubic foot, at Lowe's Home Improvement, Back to the Roots Organic 3-In-1 Seed Starting Mix 12 quart, at Walmart or Target, Back to the Roots Soils, select varieties, at Walmart, Kodiak® products, select varieties, spend $10, Wonderworks™ Keto* Friendly Cereal, Kradle, select varieties, spend $20 at Walmart, Kradle, select products, online at Chewy.com, Kradle, select varieties, online at Amazon, Kradle, select varieties, at Pet Supplies Plus, Sign up for The Club Card or The Club+ Card full-priced membership* (New Members Only), Spend $10 at CVS, Spend $30 at CVS, Fresh Step® Outstretch® Cat Litter, Bio-Oil® Skincare Oil OR Gel, select varieties, Bio-Oil® products, select varieties, Spend $90 at Star Market, Shop 2 times at Star Market, Spend $120 at Star Market, Spend $220 at Star Market, Any Star Market receipt, Beyond Meat® Plant-Based products, spend $25, Beyond Steak™ Plant-Based seared tips, 10 ounce at Target, Beyond Steak™ Plant-Based seared tips, 10 ounce, buy 2 at H-E-B, Beyond Steak™ Plant-Based seared tips, 10 ounce at H-E-B, Beyond Steak™ Plant-Based seared tips, 10 ounce, buy 2 at Target, Beyond Meat® Plant-Based products, spend $15, Beyond Meat® Plant-Based products, spend $20, Tostitos® Toppers™, Spend $140 at Shaws, Spend $185 at Shaws, Shop 2 times at Shaw's, Any Shaw's receipt, Spend $300 at Shaws, Michael Angelo's® Sauce at Walmart, Blue Apron Meal Kits, Spend $155 at Pavilions, Shop 2 times at Pavilions, Spend $100 at Pavilions, Any Pavilions receipt, Spend $270 at Pavilions
#
# Similar Category: alcohol
# Similarity Score: 0.8976600170135498
# Offers: Molson Coors®, select varieties, 12 pack+, Sign up for McAlister's Deli Rewards, tap for details, Order from Casey's app or Caseys.com, Spend $25 at Casey's, Spend $5 in-store at Casey's, Select beverages AND prepared food items at Casey's, Visit OR order online from Casey's 7 times, Spend $5 on single-serve prepared food items at Casey's, 12 Pack OR 2 Liter AND Whole Pizza Pie at Casey's, Whole Pizza at Casey's, Wings OR Cheesy Breadsticks at Casey's, Whole Pizza Pie at Casey's, Frozen OR Fountain Drink at Casey's, Spend $10 in-store at Casey's, Fresh bakery item, select varieties, at Casey's, Whole pizza at Casey's, 12 Pack OR 2 Liter AND Whole Pizza at Casey's, Frozen OR Fountain Drink at Casey's , Visit OR order online from Casey's 3 times, Visit OR order online from Casey's 5 times, 12 pack OR 2 liter AND Whole Pizza at Casey's, Whole Pizza at Casey's , Fresh Bakery Products at Casey's, select varieties, Spend $10 on Casey's branded packaged products, 2 Pack OR 2 Liter AND Whole Pizza at Casey's, Select Beverages AND Prepared Food Item at Casey's, Fresh Bakery items, select varieties, at Casey's, Spend $5 on brisket mac & cheese sandwich OR other single-serve prepared food item, Molson Coors®, select varieties, 12 Pack+, buy 2, Simply Spiked™ Lemonade 12 pack+, Simply Spiked™ Signature Peach 12-pack or larger, buy 2, Simply Spiked™ 12 pack+, Simply Spiked™ Signature Peach 12 pack+, Coors Light®, Miller Lite® OR VIZZY™ 12 pack+, Coors Light®, Miller Lite® OR VIZZY™ 12 packs+, buy 4, Coors Light®, Miller Lite® OR VIZZY™ 12 packs+, buy 2, Coors Light®, Miller Lite® OR VIZZY™ 12 packs+, buy 3, Coors Light®, Miller Lite® OR VIZZY™ 12 packs+, buy 5, André® California, Champagne OR Sparkling Wines, 750mL bottle, Spend $60 at TGI Friday's, Spend $35 at TGI Friday's, Spend $45 at TGI Friday's, Spend $25 at TGI Friday's, Wine from TheBarrelRoom.com, spend $30, Little Bites® Spend $10 at Walmart®, Sol® 6 pack+, GOYA® Coconut Water, GOYA® Adobo Seasoning, 8 ounce+, Any Vons receipt, Spend $150 at Vons, Spend $100 at Vons, Spend $275 at Vons, Shop 2 times at Vons
#
# Similar Category: dairy
# Similarity Score: 0.8667694330215454
# Offers: Sargento Sliced Cheese, spend $25, Sargento Sliced Cheese, spend $12, Sargento® products, select varieties, Sargento® products, select varieties, buy 3, Sargento Sliced Cheese, spend $18, Sargento Product, Sign up for McAlister's Deli Rewards, tap for details, Any General Mills™ products, buy 2
# Good Rewards Members Only, General Mills™ products, select brands, spend $35, General Mills™ products, select brands, spend $7 at Convenience Stores, General Mills™ products, select varieties, spend $12, :ratio™ KETO* Friendly Cereal OR Granola, Sara Lee® bread, select varieties, buy 2 at Walmart®, Sara Lee® bread select varieties, buy 2, Sara Lee® Delightful bread, buy 2, GOYA® Coconut Water, GOYA® Adobo Seasoning, 8 ounce+, Promised Land Dairy Milk, 52-ounce, Egglife Egg White Wraps at Aldi

# %%
# Define the final function that delegates to the appropriate function
def get_similar_categories_and_offers_final(category_name, top_n=5):
    # Check if the category exists in the ordered_df
    if category_name in ordered_df['Product_category'].unique():
        # Call the first function for existing categories
        similar_offers = get_similar_categories_and_offers(category_name)
        for similar_category, offers in similar_offers:
            yield similar_category, offers, None
    else:
        # Call the second function for non-existing categories
        similar_offers = get_similar_categories_and_offers_with_similarity(category_name, top_n)
        for similar_category, offers, similarity_score in similar_offers:
            yield similar_category, offers, similarity_score

# %%
# Example usage:
input_category = 'food'  # Replace with the desired input category
similar_offers = get_similar_categories_and_offers_final(input_category)
for similar_category, offers, similarity_score in similar_offers:
    print(f"Similar Category: {similar_category}")
    if similarity_score is not None:
        print(f"Similarity Score: {similarity_score}")
    print(f"Offers: {', '.join(offers)}\n")
# Out:
# Similar Category: snacks
# Similarity Score: 0.9291396141052246
# Offers: M&M'S®, select sizes, buy 1, M&M'S® chocolate candies, select varieties, SNICKERS®, select sizes, buy 1, SNICKERS® chocolate candy bar, select varieties, Little Bites® Spend $10 at Walmart®, Tostitos® Toppers™, Order from Casey's app or Caseys.com, Spend $25 at Casey's, Spend $5 in-store at Casey's, Select beverages AND prepared food items at Casey's, Visit OR order online from Casey's 7 times, Spend $5 on single-serve prepared food items at Casey's, 12 Pack OR 2 Liter AND Whole Pizza Pie at Casey's, Whole Pizza at Casey's, Wings OR Cheesy Breadsticks at Casey's, Whole Pizza Pie at Casey's, Frozen OR Fountain Drink at Casey's, Spend $10 in-store at Casey's, Fresh bakery item, select varieties, at Casey's, Whole pizza at Casey's, 12 Pack OR 2 Liter AND Whole Pizza at Casey's, Frozen OR Fountain Drink at Casey's , Visit OR order online from Casey's 3 times, Visit OR order online from Casey's 5 times, 12 pack OR 2 liter AND Whole Pizza at Casey's, Whole Pizza at Casey's , Fresh Bakery Products at Casey's, select varieties, Spend $10 on Casey's branded packaged products, 2 Pack OR 2 Liter AND Whole Pizza at Casey's, Select Beverages AND Prepared Food Item at Casey's, Fresh Bakery items, select varieties, at Casey's, Spend $5 on brisket mac & cheese sandwich OR other single-serve prepared food item, TWIX®, select sizes, TWIX®, select varieties, SKITTLES®, select varieties, SKITTLES®, select sizes, LIFE SAVERS®, LIFESAVERS®, any size, buy 1, STARBURST®, select sizes, buy 1, STARBURST®, select varieties, Hidden Valley® Ranch Salad Dressing OR Secret Sauce, select varieties, Hidden Valley® Ranch Seasoning Mix Packet, 1 count, Hidden Valley® Ranch Seasoning, select varieties, Hidden Valley® Ranch Seasoning Shaker, Hidden Valley® Ranch Night Seasoning Mix, 1 count, Sign up for McAlister's Deli Rewards, tap for details, Welch's®Fruit Snacks, select varieties, buy 2, Welch's® Zero Sugar Fruity Bites, 6 pack+, online at Amazon, Welch's® Fruit Snacks, select varieties, 6 count+, buy 3, Welch's® Fruit Snacks, 250 count, online at Amazon, Welch's® Juicefuls® Juicy Fruit Snacks, 14 count, at Target, Welch's® Fruit Snacks, select varieties, 6 count+, buy 2, Welch's®Fruit Snacks, spend $8, Welch's® Fruit 'n Yogurt® Snacks, 18 count, at Walmart, Welch's® Fruit Snacks, select varieties, 6 count+, Welch's® Juicefuls® Juicy Fruit Snacks, buy 2, Barilla® Pesto Sauce, Barilla® Pasta, select varieties, buy 2, Barilla® pasta, select varieties, buy 3, Barilla® pasta, select varieties, buy 4, Barilla® pasta, select varieties, buy 2, Nature Valley™ Protein Granola, Bimbo® sweet baked goods, buy 2, Beech-Nut snacks, select varieties, Beech-Nut pouches, buy 8, DOVE® Chocolate, select sizes, buy 1, DOVE® chocolate, select varieties, General Mills™ snacks, select brands, spend $10, Marinela® sweet baked goods, buy 2, Jack Link's®, select varieties, Any General Mills™ products, buy 2
# Good Rewards Members Only, General Mills™ products, select brands, spend $35, General Mills™ products, select brands, spend $7 at Convenience Stores, General Mills™ products, select varieties, spend $12, Glad® Trash Bags, 4 OR 8 Gallon, Glad® ForceFlex Max Strength Trash Bags, Good Humor Viennetta Frozen Vanilla Cake, Reese's Peanut Butter Bar, 6 count, at GIANT OR MARTIN’S, Shop 2 times at Safeway, Spend $210 at Safeway, Any Safeway receipt, Spend $115 at Safeway, Spend $90 at Safeway, GOYA® Coconut Water, GOYA® Adobo Seasoning, 8 ounce+, Crunchmaster® Crackers, spend $4, Brownie Brittle® Snacks, select varieties, buy 2, Chosen Foods® Mayo, select varieties, Chosen Foods® Dressings, Any Albertsons receipt, Shop 2 times at Albertsons, Spend $65 at Albertsons, Spend $110 at Albertsons, Spend $220 at Albertsons, NatuChips® Plantain Chips, :ratio™ KETO* Friendly Cereal OR Granola, Red Gold Tomato Ketchup, Red Gold Tomato Juice, Emmy's Organics® Cookies OR Brownie Snaps, Perfect Keto Barista Blend Collagen & MCTs, online at Amazon, Perfect Keto Beauty + Sleep Collagen, online at Amazon, Perfect Keto Bars, online at Amazon, Perfect Keto Collagen Peptides, online at Amazon, Perfect Keto MCT Oil Powder, online at Amazon, Perfect Keto Super Reds, online at Amazon, Perfect Keto Exogenous Ketones Powder, online at Amazon, Envy Apples pre-packed bags, Envy Apples, pre-packed bags, Gorton's, at select retailers, Gorton's Air Fried Butterfly Shrimp, at Walmart, Gorton's at select retailers
#
# Similar Category: alcohol
# Similarity Score: 0.9110013246536255
# Offers: Molson Coors®, select varieties, 12 pack+, Sign up for McAlister's Deli Rewards, tap for details, Order from Casey's app or Caseys.com, Spend $25 at Casey's, Spend $5 in-store at Casey's, Select beverages AND prepared food items at Casey's, Visit OR order online from Casey's 7 times, Spend $5 on single-serve prepared food items at Casey's, 12 Pack OR 2 Liter AND Whole Pizza Pie at Casey's, Whole Pizza at Casey's, Wings OR Cheesy Breadsticks at Casey's, Whole Pizza Pie at Casey's, Frozen OR Fountain Drink at Casey's, Spend $10 in-store at Casey's, Fresh bakery item, select varieties, at Casey's, Whole pizza at Casey's, 12 Pack OR 2 Liter AND Whole Pizza at Casey's, Frozen OR Fountain Drink at Casey's , Visit OR order online from Casey's 3 times, Visit OR order online from Casey's 5 times, 12 pack OR 2 liter AND Whole Pizza at Casey's, Whole Pizza at Casey's , Fresh Bakery Products at Casey's, select varieties, Spend $10 on Casey's branded packaged products, 2 Pack OR 2 Liter AND Whole Pizza at Casey's, Select Beverages AND Prepared Food Item at Casey's, Fresh Bakery items, select varieties, at Casey's, Spend $5 on brisket mac & cheese sandwich OR other single-serve prepared food item, Molson Coors®, select varieties, 12 Pack+, buy 2, Simply Spiked™ Lemonade 12 pack+, Simply Spiked™ Signature Peach 12-pack or larger, buy 2, Simply Spiked™ 12 pack+, Simply Spiked™ Signature Peach 12 pack+, Coors Light®, Miller Lite® OR VIZZY™ 12 pack+, Coors Light®, Miller Lite® OR VIZZY™ 12 packs+, buy 4, Coors Light®, Miller Lite® OR VIZZY™ 12 packs+, buy 2, Coors Light®, Miller Lite® OR VIZZY™ 12 packs+, buy 3, Coors Light®, Miller Lite® OR VIZZY™ 12 packs+, buy 5, André® California, Champagne OR Sparkling Wines, 750mL bottle, Spend $60 at TGI Friday's, Spend $35 at TGI Friday's, Spend $45 at TGI Friday's, Spend $25 at TGI Friday's, Wine from TheBarrelRoom.com, spend $30, Little Bites® Spend $10 at Walmart®, Sol® 6 pack+, GOYA® Coconut Water, GOYA® Adobo Seasoning, 8 ounce+, Any Vons receipt, Spend $150 at Vons, Spend $100 at Vons, Spend $275 at Vons, Shop 2 times at Vons
#
# Similar Category: candy
# Similarity Score: 0.8907543420791626
# Offers: EXTRA®, select varieties, EXTRA®, select sizes, ORBIT®, select sizes, buy 1, ORBIT®, select varieties, RESPAWN® by 5® GUM, at Walmart, STARBURST®, select sizes, buy 1, STARBURST®, select varieties
#
# Similar Category: pantry
# Similarity Score: 0.8752320408821106
# Offers: GOYA® Coconut Water, GOYA® Adobo Seasoning, 8 ounce+, Thomas'® Bagel Thins®, buy 2, Thomas'®, select varieties, spend $10, Thomas'® Bagel Thins, Sara Lee® bread, select varieties, buy 2 at Walmart®, Sara Lee® bread select varieties, buy 2, Sara Lee® Delightful bread, buy 2, Dr Pepper®, Regular OR Zero Sugar Strawberries and Cream 12 pack, at select retailers, Cheerios™ Oat Crunch Berry Cereal, BallPark® buns, buy 2, Arnold, Brownberry, Oroweat® Small Slice bread, at Walmart, Arnold, Brownberry, Oroweat® Keto bread, buy 2, Arnold® Grains Almighty, Hellmann's® OR Best Foods® Garlic Aioli OR Spicy Mayonnaise, Hellmann's® OR Best Foods® AND Sargento® Cheese Slices, Hellmann's | Best Foods Vegan Dressing or Spread, Dixon® Safety Carpenter Pencil, 10 count, at Lowe’s®, Order from Casey's app or Caseys.com, Spend $25 at Casey's, Spend $5 in-store at Casey's, Select beverages AND prepared food items at Casey's, Visit OR order online from Casey's 7 times, Spend $5 on single-serve prepared food items at Casey's, 12 Pack OR 2 Liter AND Whole Pizza Pie at Casey's, Whole Pizza at Casey's, Wings OR Cheesy Breadsticks at Casey's, Whole Pizza Pie at Casey's, Frozen OR Fountain Drink at Casey's, Spend $10 in-store at Casey's, Fresh bakery item, select varieties, at Casey's, Whole pizza at Casey's, 12 Pack OR 2 Liter AND Whole Pizza at Casey's, Frozen OR Fountain Drink at Casey's , Visit OR order online from Casey's 3 times, Visit OR order online from Casey's 5 times, 12 pack OR 2 liter AND Whole Pizza at Casey's, Whole Pizza at Casey's , Fresh Bakery Products at Casey's, select varieties, Spend $10 on Casey's branded packaged products, 2 Pack OR 2 Liter AND Whole Pizza at Casey's, Select Beverages AND Prepared Food Item at Casey's, Fresh Bakery items, select varieties, at Casey's, Spend $5 on brisket mac & cheese sandwich OR other single-serve prepared food item, Tyson Products, select varieties, spend $20 at Sam's Club, Nature Valley™ Protein Granola, CESAR® Wet Dog Food, spend $20, CESAR® Wet Dog Food Singles, Michael Angelo's® OR Rao's® Frozen Entrees, spend $10, Rao's® Frozen Pizza, Rao's®, Pasta OR Sauce, spend $10, Bimbo® sweet baked goods, buy 2, Sign up for McAlister's Deli Rewards, tap for details, Country Crock® Plant Based Butter at Walmart, Country Crock® Plant Based Cream at Walmart, Butterball, select varieties, spend $10 at Dillons Food Store, Butterball, select varieties, spend $10 at Ralphs, Butterball, select varieties, Spend $10 at Ruler Foods, Butterball, select varieties, spend $10 at King Soopers, Butterball, select varieties, spend $10 at Fred Meyer, Butterball, select varieties, spend $10 at Kroger, Butterball, select varieties, spend $10 at Smith's, Butterball, select varieties, spend $10 at Food 4 Less, Butterball, select varieties, spend $10 at Fry's Food Store, Butterball, select varieties, spend $10 at QFC, Butterball, select varieties, spend $10 at Mariano's, Butterball, select varieties, spend $10 at Pick 'n Save OR Metro Market, Artesano® buns, buy 2 at Walmart®, Hidden Valley® Ranch Salad Dressing OR Secret Sauce, select varieties, Hidden Valley® Ranch Seasoning Mix Packet, 1 count, Hidden Valley® Ranch Seasoning, select varieties, Hidden Valley® Ranch Seasoning Shaker, Hidden Valley® Ranch Night Seasoning Mix, 1 count, Simply Organic Seasoning Mixes OR Spices, Wesson® Oil Products, :ratio™ KETO* Friendly Cereal OR Granola, Bays® English Muffins, Sir Kensington's® Condiments, buy 2, Sir Kensington's® Condiments, Tyson Products, select varieties, spend $15 at Walmart, Spend $10 at Subway, Spend $25 at Subway, Spend $15 at Subway, Spend $35 at Subway, Sara Lee® or Alfaros® Artesano bread, buy 5, Sara Lee® or Alfaros® Artesano bread, spend $8, Sara Lee® or Alfaros® Artesano bread, buy 2, Sara Lee® or Alfaros® Artesano bread, spend $20, Red Gold Tomato Ketchup, Red Gold Tomato Juice, Chosen Foods® Mayo, select varieties, Chosen Foods® Dressings, Envy Apples pre-packed bags, Envy Apples, pre-packed bags, The ...
# Good Rewards Members Only, General Mills™ products, select brands, spend $35, General Mills™ products, select brands, spend $7 at Convenience Stores, General Mills™ products, select varieties, spend $12, Back to the Roots Grow Seed Starting Pots OR Germination Trays, at Walmart or Target, Back to the Roots Soils, select varieties and sizes, at Walmart, Back to the Roots Dry Plant Food, 5 pounds, at The Home Depot, Back to the Roots Garden Soil, 1 cubic foot, at Lowe's Home Improvement, Back to the Roots Raised Bed Gardening Kit with Soil, Seeds and Plant Food, at Target, Back to the Roots Microgreens Grow Kit OR Seed Refill at Walmart, Back to the Roots Soils, select varieties and sizes, at Lowes, Back to the Roots Soils, select varieties, at Walmart or Lowes, Back to the Roots Grow Kits at Walmart or The Home Depot, Back to the Roots Grow Hydroponic Grow Kit OR Refill Bundle at Walmart, Back to the Roots Seeds, at Walmart, Back to the Roots Organic Kits and Planters, at Target, Back to the Roots Potting Mix, 1 cubic foot, at Lowe's Home Improvement, Back to the Roots Organic 3-In-1 Seed Starting Mix 12 quart, at Walmart or Target, Back to the Roots Soils, select varieties, at Walmart, Kodiak® products, select varieties, spend $10, Wonderworks™ Keto* Friendly Cereal, Kradle, select varieties, spend $20 at Walmart, Kradle, select products, online at Chewy.com, Kradle, select varieties, online at Amazon, Kradle, select varieties, at Pet Supplies Plus, Sign up for The Club Card or The Club+ Card full-priced membership* (New Members Only), Spend $10 at CVS, Spend $30 at CVS, Fresh Step® Outstretch® Cat Litter, Bio-Oil® Skincare Oil OR Gel, select varieties, Bio-Oil® products, select varieties, Spend $90 at Star Market, Shop 2 times at Star Market, Spend $120 at Star Market, Spend $220 at Star Market, Any Star Market receipt, Beyond Meat® Plant-Based products, spend $25, Beyond Steak™ Plant-Based seared tips, 10 ounce at Target, Beyond Steak™ Plant-Based seared tips, 10 ounce, buy 2 at H-E-B, Beyond Steak™ Plant-Based seared tips, 10 ounce at H-E-B, Beyond Steak™ Plant-Based seared tips, 10 ounce, buy 2 at Target, Beyond Meat® Plant-Based products, spend $15, Beyond Meat® Plant-Based products, spend $20, Tostitos® Toppers™, Spend $140 at Shaws, Spend $185 at Shaws, Shop 2 times at Shaw's, Any Shaw's receipt, Spend $300 at Shaws, Michael Angelo's® Sauce at Walmart, Blue Apron Meal Kits, Spend $155 at Pavilions, Shop 2 times at Pavilions, Spend $100 at Pavilions, Any Pavilions receipt, Spend $270 at Pavilions
#
# Similar Category: dairy
# Similarity Score: 0.859916627407074
# Offers: Sargento Sliced Cheese, spend $25, Sargento Sliced Cheese, spend $12, Sargento® products, select varieties, Sargento® products, select varieties, buy 3, Sargento Sliced Cheese, spend $18, Sargento Product, Sign up for McAlister's Deli Rewards, tap for details, Any General Mills™ products, buy 2
# Good Rewards Members Only, General Mills™ products, select brands, spend $35, General Mills™ products, select brands, spend $7 at Convenience Stores, General Mills™ products, select varieties, spend $12, :ratio™ KETO* Friendly Cereal OR Granola, Sara Lee® bread, select varieties, buy 2 at Walmart®, Sara Lee® bread select varieties, buy 2, Sara Lee® Delightful bread, buy 2, GOYA® Coconut Water, GOYA® Adobo Seasoning, 8 ounce+, Promised Land Dairy Milk, 52-ounce, Egglife Egg White Wraps at Aldi
